# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

sns.set(style='white')

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('whisky.csv')

# %%
df.head()
# Out:
#                                                 name  \
# 0                            Glenfiddich 21 Year Old
# 1      Gordon & Macphail Glen Grant 1966 45 Year Old
# 2  Gordon & Macphail Glen Grant 1962 43 Year Old ...
# 3                   Linkwood 1966 Private Collection
# 4                   Mortlach 1974 Private Collection
#
#                                                 href      price
# 0  https://www.whiskyshop.com/glenfiddich-21-year...    £150.00
# 1  https://www.whiskyshop.com/gordon-macphail-gle...    £780.00
# 2  https://www.whiskyshop.com/gordon-macphail-gle...  £1,499.00
# 3  https://www.whiskyshop.com/linkwood-1966-priva...  £6,500.00
# 4  https://www.whiskyshop.com/mortlach-1974-priva...  £1,950.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477 entries, 0 to 476
# Data columns (total 3 columns):
# name     477 non-null object
# href     477 non-null object
# price    463 non-null object
# dtypes: object(3)
# memory usage: 11.3+ KB

# %%
df[df['price'].isnull()]
# Out:
#                                                   name  \
# 32           Arran 1996 TWS Exclusive Single Cask #736
# 51                Arran 1999 #225 The W Club Exclusive
# 83          Johnnie Walker Gold Icon 200th Anniversary
# 119                Macallan 50 Year Old Red Collection
# 154             Macallan 1940 37 Year Old Fine & Rare
# 160                Wemyss Malts Velvet Fig 25 Year Old
# 182                 Glendronach 1993 26 Year Old #7434
# 183                The Loch Fyne Gift Box Pick 'n' Mix
# 214                                     Longrow Peated
# 225  GlenDronach 1992 26 Year Old The Whisky Shop E...
# 246                           Glendronach Peated Cask
# 453                           Glenmorangie 18 Year Old
# 471                      Old Fashioned Cocktail Bundle
# 476                                            Glayva
#
#                                                   href price
# 32   https://www.whiskyshop.com/arran-1996-736-the-...   NaN
# ...

# %%
df[df['name']=='Compass Box Magic Cask']
# Out:
#                       name                                               href  \
# 73  Compass Box Magic Cask  https://www.whiskyshop.com/compass-box-magic-cask
#
#       price
# 73  £142.99
